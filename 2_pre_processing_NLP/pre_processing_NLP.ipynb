# %%
import pandas as pd
from geopy.distance import geodesic
from langdetect import detect, DetectorFactory
import matplotlib.pyplot as plt
import spacy
import re
import string
from textblob import TextBlob
import hashlib
from langdetect.lang_detect_exception import LangDetectException
import time
from deep_translator import GoogleTranslator
import numpy as np
import dateparser
from datetime import datetime
from spacy.lang.en.stop_words import STOP_WORDS

# %% [markdown]
# # === 1. LOADING FILES ===

# %%
# Caminhos para os CSVs (ajusta conforme o necessário)
caminho_avaliacoes = "C:/Users/Fernanda Costa/OneDrive - Universidade de Aveiro/Desktop/seminar_project/1_data_collection/google_places_API/csv/google_places_AMP_with_coordinates.csv"
caminho_comentarios = "C:/Users/Fernanda Costa/OneDrive - Universidade de Aveiro/Desktop/seminar_project/1_data_collection/google_places_API/csv/comments_google_maps_AMP.csv"

# Leitura dos dados
avaliacoes = pd.read_csv(caminho_avaliacoes)
comentarios = pd.read_csv(caminho_comentarios)

# %% [markdown]
# # === 2. PRE-PROCESSING OF RATINGS ===

# %%
avaliacoes.head()
# Out:
#    Cidade   Categoria                 Nome  Rating  \
# 0  Arouca  restaurant  Tasquinha da Quinta     4.6
# 1  Arouca  restaurant         A Assembleia     4.5
# 2  Arouca  restaurant           Parlamento     4.6
# 3  Arouca  restaurant        Casa Testinha     4.5
# 4  Arouca  restaurant         Pedestre 142     4.4
#
#                                             Endereço  \
# 0         R. 1º de Maio 3, 4540-121 Arouca, Portugal
# 1       Tv. da Ribeira 11, 4540-102 Arouca, Portugal
# 2        Tv. da Ribeira 2, 4540-148 Arouca, Portugal
# 3         R. 1º de Maio 4, 4540-113 Arouca, Portugal
# 4  R. Dr. Ângelo Miranda 142 RC, 4540-140 Arouca,...
#
#                                                Tipos   Latitude  Longitude  \
# 0  restaurant, food, point_of_interest, establish...  40.929109  -8.245191
# 1  restaurant, bar, food, point_of_interest, esta...  40.928766  -8.247588
# 2  restaurant, food, point_of_interest, establish...  40.929011  -8.247392
# 3  restaurant, food, point_of_interest, establish...  40.928876  -8.245147
# 4  restaurant, food, point_of_interest, establish...  40.930185  -8.253210
#
#    Total_Reviews
# 0         2154.0
# 1         1788.0
# 2         2469.0
# 3          623.0
# 4         1047.0

# %%
avaliacoes['Cidade'].unique()
# Out:
# array(['Arouca', 'Espinho', 'Gondomar', 'Maia', 'Matosinhos',
#        'Oliveira de Azeméis', 'Paredes', 'Penafiel', 'Porto',
#        'Póvoa de Varzim', 'Santa Maria da Feira', 'Santo Tirso',
#        'São João da Madeira', 'Trofa', 'Valongo', 'Vila do Conde',
#        'Vila Nova de Gaia'], dtype=object)

# %%
avaliacoes.columns
# Out:
# Index(['Cidade', 'Categoria', 'Nome', 'Rating', 'Endereço', 'Tipos',
#        'Latitude', 'Longitude', 'Total_Reviews'],
#       dtype='object')

# %%
avaliacoes['Rating'].isnull().sum()
# Out:
# 140

# %%
avaliacoes['Total_Reviews'].isnull().sum()
# Out:
# 4179

# %%
((avaliacoes["Total_Reviews"] == 0) & (avaliacoes["Total_Reviews"].notnull())).sum()
# Out:
# 0

# %%
avaliacoes.duplicated(subset=["Endereço"]).sum()
# Out:
# 1803

# %%
endereco_repetido = avaliacoes["Endereço"][avaliacoes["Endereço"].duplicated()].iloc[0]
avaliacoes[avaliacoes["Endereço"] == endereco_repetido]
# Out:
#      Cidade   Categoria                          Nome  Rating  \
# 7    Arouca  restaurant               Café Arouquense     4.3
# 20   Arouca  restaurant              Sabores da serra     4.1
# 94   Arouca         bar  BOM COPO - restaurante & bar     4.8
# 119  Arouca        cafe               Café Arouquense     4.3
# 133  Arouca        cafe             Bakery Village II     4.4
# 151  Arouca        cafe              Sabores da serra     4.1
#
#                                        Endereço  \
# 7    Av. 25 de Abril, 4540-102 Arouca, Portugal
# 20   Av. 25 de Abril, 4540-102 Arouca, Portugal
# 94   Av. 25 de Abril, 4540-102 Arouca, Portugal
# 119  Av. 25 de Abril, 4540-102 Arouca, Portugal
# 133  Av. 25 de Abril, 4540-102 Arouca, Portugal
# 151  Av. 25 de Abril, 4540-102 Arouca, Portugal
#
#                                                  Tipos   Latitude  Longitude  \
# 7    cafe, restaurant, food, point_of_interest, est...  40.928469  -8.245599
# 20   restaurant, food, point_of_interest, establish...  40.928561  -8.244947
# 94   restaurant, food, point_of_interest, establish...  40.928572  -8.244460
# 119  cafe, restaurant, food, point_of_interest, est...  40.928469  -8.245599
# 133  cafe, store, food, point_of_interest, establis...  40.927949  -8.251804
# 151  restaurant, food, point_of_interest, establish...  40.928561  -8.244947
#
#      Total_Reviews
# 7            901.0
# 20            16.0
# 94            11.0
# 119          901.0
# 133          378.0
# 151           16.0

# %%
avaliacoes.duplicated(subset=["Nome", "Endereço"]).sum()
# Out:
# 1569

# %%
avaliacoes["Cidade"].nunique()
# Out:
# 17

# %%
avaliacoes["Categoria"].unique()
# Out:
# array(['restaurant', 'museum', 'hotel', 'bar', 'tourist_attraction',
#        'cafe', 'church', 'park', 'natural_feature', 'viewpoint', 'trail',
#        'lodging'], dtype=object)

# %%
print("Mínimo:", avaliacoes["Rating"].min())
print("Máximo:", avaliacoes["Rating"].max())
# Out:
# Mínimo: 1.0
# Máximo: 5.0

# %%
def gerar_hash(nome, endereco):
    texto = (nome + endereco).encode("utf-8")
    return hashlib.sha1(texto).hexdigest()[:8]  # 8 caracteres de hash

avaliacoes["id_unico"] = avaliacoes.apply(
    lambda row: gerar_hash(row["Nome"], row["Endereço"]),
    axis=1
)

# %%
avaliacoes.head()
# Out:
#    Cidade   Categoria                 Nome  Rating  \
# 0  Arouca  restaurant  Tasquinha da Quinta     4.6
# 1  Arouca  restaurant         A Assembleia     4.5
# 2  Arouca  restaurant           Parlamento     4.6
# 3  Arouca  restaurant        Casa Testinha     4.5
# 4  Arouca  restaurant         Pedestre 142     4.4
#
#                                             Endereço  \
# 0         R. 1º de Maio 3, 4540-121 Arouca, Portugal
# 1       Tv. da Ribeira 11, 4540-102 Arouca, Portugal
# 2        Tv. da Ribeira 2, 4540-148 Arouca, Portugal
# 3         R. 1º de Maio 4, 4540-113 Arouca, Portugal
# 4  R. Dr. Ângelo Miranda 142 RC, 4540-140 Arouca,...
#
#                                                Tipos   Latitude  Longitude  \
# 0  restaurant, food, point_of_interest, establish...  40.929109  -8.245191
# 1  restaurant, bar, food, point_of_interest, esta...  40.928766  -8.247588
# 2  restaurant, food, point_of_interest, establish...  40.929011  -8.247392
# 3  restaurant, food, point_of_interest, establish...  40.928876  -8.245147
# 4  restaurant, food, point_of_interest, establish...  40.930185  -8.253210
#
#    Total_Reviews  id_unico
# 0         2154.0  d111a3c6
# 1         1788.0  54221336
# 2         2469.0  ca96ed20
# 3          623.0  348acace
# 4         1047.0  55a3ab0d

# %%
# Eliminar as linhas onde o Rating é null (ou seja, NaN)
avaliacoes = avaliacoes[avaliacoes["Rating"].notnull()]

# Substituir os valores null (ou NaN) por 0 na coluna Total_Reviews
avaliacoes["Total_Reviews"] = avaliacoes["Total_Reviews"].fillna(0)

# Garantir que Total_Reviews fica como número inteiro
avaliacoes["Total_Reviews"] = avaliacoes["Total_Reviews"].astype(int)

# %%
avaliacoes.head()
# Out:
#    Cidade   Categoria                 Nome  Rating  \
# 0  Arouca  restaurant  Tasquinha da Quinta     4.6
# 1  Arouca  restaurant         A Assembleia     4.5
# 2  Arouca  restaurant           Parlamento     4.6
# 3  Arouca  restaurant        Casa Testinha     4.5
# 4  Arouca  restaurant         Pedestre 142     4.4
#
#                                             Endereço  \
# 0         R. 1º de Maio 3, 4540-121 Arouca, Portugal
# 1       Tv. da Ribeira 11, 4540-102 Arouca, Portugal
# 2        Tv. da Ribeira 2, 4540-148 Arouca, Portugal
# 3         R. 1º de Maio 4, 4540-113 Arouca, Portugal
# 4  R. Dr. Ângelo Miranda 142 RC, 4540-140 Arouca,...
#
#                                                Tipos   Latitude  Longitude  \
# 0  restaurant, food, point_of_interest, establish...  40.929109  -8.245191
# 1  restaurant, bar, food, point_of_interest, esta...  40.928766  -8.247588
# 2  restaurant, food, point_of_interest, establish...  40.929011  -8.247392
# 3  restaurant, food, point_of_interest, establish...  40.928876  -8.245147
# 4  restaurant, food, point_of_interest, establish...  40.930185  -8.253210
#
#    Total_Reviews  id_unico
# 0           2154  d111a3c6
# 1           1788  54221336
# 2           2469  ca96ed20
# 3            623  348acace
# 4           1047  55a3ab0d

# %%
avaliacoes['Cidade'].unique()
# Out:
# array(['Arouca', 'Espinho', 'Gondomar', 'Maia', 'Matosinhos',
#        'Oliveira de Azeméis', 'Paredes', 'Penafiel', 'Porto',
#        'Póvoa de Varzim', 'Santa Maria da Feira', 'Santo Tirso',
#        'São João da Madeira', 'Trofa', 'Valongo', 'Vila do Conde',
#        'Vila Nova de Gaia'], dtype=object)

# %%
avaliacoes["id_unico"].nunique()
# Out:
# 3498

# %%
def classificar_por_categoria(cat):
    cat = str(cat).lower()
    if cat in ["restaurant", "cafe", "bar", "bakery", "store", "night_club"]:
        return "Serviços"
    elif cat in ["museum", "art_gallery", "tourist_attraction", "church"]:
        return "Turismo Cultural"
    elif cat in ["park", "natural_feature", "viewpoint", "trail", "scenic_spot"]:
        return "Recursos Naturais"
    elif cat in ["hotel", "lodging", "hostel", "guest_house"]:
        return "Alojamento"
    else:
        return "Outro"


avaliacoes["Grupo_Tematico"] = avaliacoes["Categoria"].apply(classificar_por_categoria)

# %%
avaliacoes["Grupo_Tematico"].unique()
# Out:
# array(['Serviços', 'Turismo Cultural', 'Alojamento', 'Recursos Naturais'],
#       dtype=object)

# %%
avaliacoes['Cidade'].unique()
# Out:
# array(['Arouca', 'Espinho', 'Gondomar', 'Maia', 'Matosinhos',
#        'Oliveira de Azeméis', 'Paredes', 'Penafiel', 'Porto',
#        'Póvoa de Varzim', 'Santa Maria da Feira', 'Santo Tirso',
#        'São João da Madeira', 'Trofa', 'Valongo', 'Vila do Conde',
#        'Vila Nova de Gaia'], dtype=object)

# %%
# Função para contar locais semelhantes por categoria e proximidade, ignorando coordenadas nulas
def contar_proximos(row, df, raio=100):
    # Verifica se a linha tem coordenadas válidas
    if pd.isna(row["Latitude"]) or pd.isna(row["Longitude"]):
        return np.nan  # ou 0, dependendo do que preferires

    lat_lon_ref = (row["Latitude"], row["Longitude"])
    
    mesma_categoria = df[df["Categoria"] == row["Categoria"]]

    # Aplicar cálculo apenas às linhas com coordenadas válidas
    mesma_categoria = mesma_categoria[
        mesma_categoria["Latitude"].notna() & mesma_categoria["Longitude"].notna()
    ]

    count = mesma_categoria.apply(
        lambda x: geodesic(lat_lon_ref, (x["Latitude"], x["Longitude"])).meters < raio
                  and x["id_unico"] != row["id_unico"],
        axis=1
    ).sum()
    
    return count

# Aplicar a função
avaliacoes["Locais_Semelhantes_Perto"] = avaliacoes.apply(
    lambda row: contar_proximos(row, avaliacoes),
    axis=1
)

# %%
avaliacoes.head()
# Out:
#    Cidade   Categoria                 Nome  Rating  \
# 0  Arouca  restaurant  Tasquinha da Quinta     4.6
# 1  Arouca  restaurant         A Assembleia     4.5
# 2  Arouca  restaurant           Parlamento     4.6
# 3  Arouca  restaurant        Casa Testinha     4.5
# 4  Arouca  restaurant         Pedestre 142     4.4
#
#                                             Endereço  \
# 0         R. 1º de Maio 3, 4540-121 Arouca, Portugal
# 1       Tv. da Ribeira 11, 4540-102 Arouca, Portugal
# 2        Tv. da Ribeira 2, 4540-148 Arouca, Portugal
# 3         R. 1º de Maio 4, 4540-113 Arouca, Portugal
# 4  R. Dr. Ângelo Miranda 142 RC, 4540-140 Arouca,...
#
#                                                Tipos   Latitude  Longitude  \
# 0  restaurant, food, point_of_interest, establish...  40.929109  -8.245191
# 1  restaurant, bar, food, point_of_interest, esta...  40.928766  -8.247588
# 2  restaurant, food, point_of_interest, establish...  40.929011  -8.247392
# 3  restaurant, food, point_of_interest, establish...  40.928876  -8.245147
# 4  restaurant, food, point_of_interest, establish...  40.930185  -8.253210
#
#    Total_Reviews  id_unico Grupo_Tematico  Locais_Semelhantes_Perto
# 0           2154  d111a3c6       Serviços                       5.0
# 1           1788  54221336       Serviços                       5.0
# 2           2469  ca96ed20       Serviços                       6.0
# 3            623  348acace       Serviços                       5.0
# 4           1047  55a3ab0d       Serviços                       0.0

# %%
variacoes = avaliacoes.groupby("id_unico")["Locais_Semelhantes_Perto"].nunique()
variacoes_multiplos = variacoes[variacoes > 1]
print("Número de id_unico com valores diferentes de Locais_Semelhantes_Perto:", len(variacoes_multiplos))
# Out:
# Número de id_unico com valores diferentes de Locais_Semelhantes_Perto: 54

# %%
exemplo_id = variacoes_multiplos.index[0]
print("Exemplo de id_unico com valores diferentes:", exemplo_id)
# Out:
# Exemplo de id_unico com valores diferentes: 066473c6

# %%
avaliacoes[avaliacoes["id_unico"] == exemplo_id]
# Out:
#      Cidade   Categoria                 Nome  Rating  \
# 5    Arouca  restaurant  Tasquinho do Parque     4.5
# 87   Arouca         bar  Tasquinho do Parque     4.5
# 132  Arouca        cafe  Tasquinho do Parque     4.5
# 195  Arouca        park  Tasquinho do Parque     4.5
#
#                                               Endereço  \
# 5    R. Dom Afonso Henriques 57 4540, Arouca, Portugal
# 87   R. Dom Afonso Henriques 57 4540, Arouca, Portugal
# 132  R. Dom Afonso Henriques 57 4540, Arouca, Portugal
# 195  R. Dom Afonso Henriques 57 4540, Arouca, Portugal
#
#                                                  Tipos   Latitude  Longitude  \
# 5    restaurant, food, point_of_interest, establish...  40.927645  -8.248854
# 87   restaurant, food, point_of_interest, establish...  40.927645  -8.248854
# 132  restaurant, food, point_of_interest, establish...  40.927645  -8.248854
# 195  restaurant, food, point_of_interest, establish...  40.927645  -8.248854
#
#      Total_Reviews  id_unico     Grupo_Tematico  Locais_Semelhantes_Perto
# 5              203  066473c6           Serviços                       1.0
# 87             203  066473c6           Serviços                       0.0
# 132            203  066473c6           Serviços                       1.0
# 195            203  066473c6  Recursos Naturais                       2.0

# %%
# Agrupaste a densidade por local (id_unico)
densidade_agrupada = avaliacoes.groupby('id_unico')['Locais_Semelhantes_Perto'].max().reset_index()

# Eliminaste duplicados para cada id_unico e retiraste a coluna antiga da densidade
ratings_unicos = avaliacoes.drop_duplicates(subset='id_unico').drop(columns=['Locais_Semelhantes_Perto'])

# Juntaste a densidade máxima ao DataFrame limpo — resultado final ficou em:
ratings_final = ratings_unicos.merge(densidade_agrupada, on='id_unico', how='left')

avaliacoes = ratings_final.copy()

# %%
avaliacoes.head(5)
# Out:
#    Cidade   Categoria                 Nome  Rating  \
# 0  Arouca  restaurant  Tasquinha da Quinta     4.6
# 1  Arouca  restaurant         A Assembleia     4.5
# 2  Arouca  restaurant           Parlamento     4.6
# 3  Arouca  restaurant        Casa Testinha     4.5
# 4  Arouca  restaurant         Pedestre 142     4.4
#
#                                             Endereço  \
# 0         R. 1º de Maio 3, 4540-121 Arouca, Portugal
# 1       Tv. da Ribeira 11, 4540-102 Arouca, Portugal
# 2        Tv. da Ribeira 2, 4540-148 Arouca, Portugal
# 3         R. 1º de Maio 4, 4540-113 Arouca, Portugal
# 4  R. Dr. Ângelo Miranda 142 RC, 4540-140 Arouca,...
#
#                                                Tipos   Latitude  Longitude  \
# 0  restaurant, food, point_of_interest, establish...  40.929109  -8.245191
# 1  restaurant, bar, food, point_of_interest, esta...  40.928766  -8.247588
# 2  restaurant, food, point_of_interest, establish...  40.929011  -8.247392
# 3  restaurant, food, point_of_interest, establish...  40.928876  -8.245147
# 4  restaurant, food, point_of_interest, establish...  40.930185  -8.253210
#
#    Total_Reviews  id_unico Grupo_Tematico  Locais_Semelhantes_Perto
# 0           2154  d111a3c6       Serviços                       6.0
# 1           1788  54221336       Serviços                       6.0
# 2           2469  ca96ed20       Serviços                       7.0
# 3            623  348acace       Serviços                       6.0
# 4           1047  55a3ab0d       Serviços                       0.0

# %% [markdown]
# # === 3. PRE-PROCESSING COMMENTS ===

# %%
comentarios.head()
# Out:
#    Cidade    Categoria           Nome_Local           Autor  \
# 0  Arouca  restaurante  Tasquinha da Quinta              IC
# 1  Arouca  restaurante  Tasquinha da Quinta    Preetam Nath
# 2  Arouca  restaurante  Tasquinha da Quinta         Roya MJ
# 3  Arouca  restaurante  Tasquinha da Quinta   Jonathan lugo
# 4  Arouca  restaurante  Tasquinha da Quinta  Benjamim Nande
#
#                                                Texto           Data  Rating
# 0  I came here as part of a tour, and this restau...  10 months ago       5
# 1  Has to be the most delicious veal I've had in ...     a year ago       5
# 2  Came here as part of a tour and very much appr...     a year ago       5
# 3  Very good food and an excellent place to eat! ...     a year ago       5
# 4  Great place for a good typical Portuguese food...   4 months ago       5

# %%
(comentarios["Nome_Local"] == "Tasquinha da Quinta").sum()
# Out:
# 5

# %%
comentarios["Cidade"].unique()
# Out:
# array(['Arouca', 'Espinho', 'Gondomar', 'Maia', 'Matosinhos',
#        'Oliveira de Azeméis', 'Paredes', 'Penafiel', 'Porto',
#        'Póvoa de Varzim', 'Santa Maria da Feira', 'Santo Tirso',
#        'São João da Madeira', 'Trofa', 'Valongo', 'Vila do Conde',
#        'Vila Nova de Gaia'], dtype=object)

# %%
comentarios['Rating'].unique()
# Out:
# array([5, 3, 2, 1, 4], dtype=int64)

# %%
comentarios['Rating'].isnull().sum()
# Out:
# 0

# %%
comentarios['Texto'].isnull().sum()
# Out:
# 149

# %%
comentarios[comentarios['Texto'].isnull()].head()
# Out:
#      Cidade    Categoria                                 Nome_Local  \
# 186  Arouca  restaurante                                 O Canastro
# 321  Arouca        hotel                       Arouca Guest House 2
# 334  Arouca        hotel  MS Collection Arouca - Mosteiro de Arouca
# 335  Arouca        hotel  MS Collection Arouca - Mosteiro de Arouca
# 590  Arouca        praia                    Casa do Tanque - Arouca
#
#                    Autor Texto           Data  Rating
# 186      Cláudia Martins   NaN   2 months ago       5
# 321                 Chus   NaN  10 months ago       5
# 334          Vítor Neves   NaN     a week ago       5
# 335  Alexandra Barreiros   NaN     a year ago       5
# 590           Hugo Cunha   NaN    2 years ago       5

# %%
# Eliminar comentários em falta
comentarios = comentarios.dropna(subset=["Texto"])

# Remover espaços e garantir tipo texto
comentarios["Texto"] = comentarios["Texto"].astype(str).str.strip()

# %%
comentarios.shape[0]
# Out:
# 9063

# %%
comentarios.head()
# Out:
#    Cidade    Categoria           Nome_Local           Autor  \
# 0  Arouca  restaurante  Tasquinha da Quinta              IC
# 1  Arouca  restaurante  Tasquinha da Quinta    Preetam Nath
# 2  Arouca  restaurante  Tasquinha da Quinta         Roya MJ
# 3  Arouca  restaurante  Tasquinha da Quinta   Jonathan lugo
# 4  Arouca  restaurante  Tasquinha da Quinta  Benjamim Nande
#
#                                                Texto           Data  Rating
# 0  I came here as part of a tour, and this restau...  10 months ago       5
# 1  Has to be the most delicious veal I've had in ...     a year ago       5
# 2  Came here as part of a tour and very much appr...     a year ago       5
# 3  Very good food and an excellent place to eat! ...     a year ago       5
# 4  Great place for a good typical Portuguese food...   4 months ago       5

# %%
# Função que tenta detetar o idioma, tratando erros e textos vazios
def detetar_idioma(texto):
    try:
        if pd.isna(texto) or str(texto).strip() == "":
            return "desconhecido"
        return detect(texto)
    except LangDetectException:
        return "erro"

# Aplicar ao DataFrame
comentarios["Idioma"] = comentarios["Texto"].apply(detetar_idioma)

# %%
comentarios.head()
# Out:
#    Cidade    Categoria           Nome_Local           Autor  \
# 0  Arouca  restaurante  Tasquinha da Quinta              IC
# 1  Arouca  restaurante  Tasquinha da Quinta    Preetam Nath
# 2  Arouca  restaurante  Tasquinha da Quinta         Roya MJ
# 3  Arouca  restaurante  Tasquinha da Quinta   Jonathan lugo
# 4  Arouca  restaurante  Tasquinha da Quinta  Benjamim Nande
#
#                                                Texto           Data  Rating  \
# 0  I came here as part of a tour, and this restau...  10 months ago       5
# 1  Has to be the most delicious veal I've had in ...     a year ago       5
# 2  Came here as part of a tour and very much appr...     a year ago       5
# 3  Very good food and an excellent place to eat! ...     a year ago       5
# 4  Great place for a good typical Portuguese food...   4 months ago       5
#
#   Idioma
# 0     en
# 1     en
# 2     en
# 3     en
# 4     en

# %%
comentarios['Data'].unique()
# Out:
# array(['10 months ago', 'a year ago', '4 months ago', '5 months ago',
#        '7 months ago', '3 years ago', '4 years ago', '2 years ago',
#        '11 months ago', '6 years ago', '8 years ago', '5 years ago',
#        '8 months ago', '3 weeks ago', '9 months ago', '6 months ago',
#        'a month ago', 'a week ago', '7 years ago', '10 years ago',
#        '3 months ago', 'in the last week', '2 months ago', '9 years ago',
#        '2 weeks ago', '4 weeks ago', '11 years ago', '12 months ago'],
#       dtype=object)

# %%
# Converter a coluna de datas relativas para datas reais
comentarios['Data_Convertida'] = comentarios['Data'].apply(lambda x: dateparser.parse(x, settings={'RELATIVE_BASE': datetime.today()}))

# Ver exemplo
print(comentarios[['Data', 'Data_Convertida']].head())
# Out:
#             Data            Data_Convertida
# 0  10 months ago 2024-08-11 18:20:59.350385
# 1     a year ago 2024-06-11 18:20:59.441467
# 2     a year ago 2024-06-11 18:20:59.458231
# 3     a year ago 2024-06-11 18:20:59.458231
# 4   4 months ago 2025-02-11 18:20:59.458231

# %%
comentarios.head(3)
# Out:
#    Cidade    Categoria           Nome_Local         Autor  \
# 0  Arouca  restaurante  Tasquinha da Quinta            IC
# 1  Arouca  restaurante  Tasquinha da Quinta  Preetam Nath
# 2  Arouca  restaurante  Tasquinha da Quinta       Roya MJ
#
#                                                Texto           Data  Rating  \
# 0  I came here as part of a tour, and this restau...  10 months ago       5
# 1  Has to be the most delicious veal I've had in ...     a year ago       5
# 2  Came here as part of a tour and very much appr...     a year ago       5
#
#   Idioma            Data_Convertida
# 0     en 2024-08-11 18:20:59.350385
# 1     en 2024-06-11 18:20:59.441467
# 2     en 2024-06-11 18:20:59.458231

# %%
# Converter para apenas data (datetime.date)
comentarios['Data_Convertida'] = pd.to_datetime(comentarios['Data_Convertida']).dt.date
comentarios['Data_Convertida'] = pd.to_datetime(comentarios['Data_Convertida'])

# %%
comentarios['Data_Convertida'].isnull().sum()
# Out:
# 0

# %%
comentarios.head(5)
# Out:
#    Cidade    Categoria           Nome_Local           Autor  \
# 0  Arouca  restaurante  Tasquinha da Quinta              IC
# 1  Arouca  restaurante  Tasquinha da Quinta    Preetam Nath
# 2  Arouca  restaurante  Tasquinha da Quinta         Roya MJ
# 3  Arouca  restaurante  Tasquinha da Quinta   Jonathan lugo
# 4  Arouca  restaurante  Tasquinha da Quinta  Benjamim Nande
#
#                                                Texto           Data  Rating  \
# 0  I came here as part of a tour, and this restau...  10 months ago       5
# 1  Has to be the most delicious veal I've had in ...     a year ago       5
# 2  Came here as part of a tour and very much appr...     a year ago       5
# 3  Very good food and an excellent place to eat! ...     a year ago       5
# 4  Great place for a good typical Portuguese food...   4 months ago       5
#
#   Idioma Data_Convertida
# 0     en      2024-08-11
# 1     en      2024-06-11
# 2     en      2024-06-11
# 3     en      2024-06-11
# 4     en      2025-02-11

# %% [markdown]
# # === 4. NLP OF COMMENTS ===

# %%
# Para garantir resultados consistentes
DetectorFactory.seed = 0

# Função robusta para detetar idioma
def detectar_idioma(texto):
    try:
        return detect(str(texto))
    except LangDetectException:
        return "unknown"

# Criar nova coluna com idioma detetado
comentarios['Idioma'] = comentarios['Texto'].apply(detectar_idioma)

# %%
# Função para traduzir
def traduzir_para_ingles(texto):
    try:
        if not texto or pd.isna(texto):
            return texto
        time.sleep(1.2)  # espera 1.2 segundos
        return GoogleTranslator(source='auto', target='en').translate(texto)
    except Exception as e:
        print(f"Erro ao traduzir: {e}")
        return texto

# Criar nova coluna 'translated_text' com o texto original ou traduzido
comentarios['translated_text'] = comentarios.apply(
    lambda row: row['Texto'] if row['Idioma'] == 'en' else traduzir_para_ingles(row['Texto']),
    axis=1
)
# Out:
# Erro ao traduzir: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Erro ao traduzir: ('Connection aborted.', ConnectionAbortedError(10053, 'Uma ligação estabelecida foi anulada pelo software no computador anfitrião', None, 10053, None))
# Erro ao traduzir: HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=auto&q=Eu+n%C3%A3o+gostava+de+sushi+mas+fui+ao+sabores+da+%C3%81sia+contra+a+minha+vontade+e+quando+provei+eu+amei%2C+5+estrelas+pelo+antendimento+e+pela+comida. (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023B1B5428D0>: Failed to resolve 'translate.google.com' ([Errno 11001] getaddrinfo failed)"))
# Erro ao traduzir: HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=auto&q=Nice+pizza%21+Recommend (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023B1B66ADE0>: Failed to resolve 'translate.google.com' ([Errno 11001] getaddrinfo failed)"))
# Erro ao traduzir: HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=auto&q=Muito+acolhedor+e+sossegado.+Recomendo (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000023B1B541640>: Failed to establish a new connection: [WinError 10053] Uma ligação estabelecida foi anulada pelo software no computador anfitrião'))
# Erro ao traduzir: HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=auto&q=Nous+avons+%C3%A9t%C3%A9+tr%C3%A8s+satisfaits++de+notre+s%C3%A9jour.%0ATr%C3%A8s+bon+accueil.%0ALes+chambres+sont+tr%C3%A8s+belles+et+tr%C3%A8s+propres.++Salle+de+bain+idem.%0AL+ensemble+du+b%C3%A2timent+est+vraiment+typique+de+la+r%C3%A9gion+avec+des+murs+en+granite.%0ALe+petit+d%C3%A9jeuner+est+tr%C3%A8s+bien+et+complet+avec+sucr%C3%A9+et+sal%C3%A9.%0AR%C3%A9servation+bien+anticip%C3%A9e+indispensable.%0AJe+recommande+vivement. (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023B1B55CFE0>: Failed to resolve 'translate.google.com' ([Errno 11001] getaddrinfo failed)"))
# Erro ao traduzir: HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=auto&q=Horr%C3%ADvel+%21%21%21%0A%0AFizemos+reserva+noutro+alojamento+%22Suite+Douro%22+%28ou+com+o+nome+Douro+Green+Villa+que+pelos+vistos+%C3%A9+tudo+o+mesmo%29.%0A%C3%80+chegada+da+morada+indicada+no+Booking%2C+vimos+uma+casa+meia+abandonada.+Ligamos+%C3%A0+senhora+a+mesma+disse+que+a+morada+estava+errada+e+indicou-nos+para+este%21%0A%0AChegamos%2C+parecia+um+AL+normal.%0AAo+subirmos%2C+estavam+a+tentar+arranjar+a+porta+do+quarto+onde+ir%C3%ADamos+ficar+pois+a+mesma+estava+com+a+fechadura+estragada.%0A-+Quarto+com+aspecto+duvidoso%2C+len%C3%A7%C3%B3is+e+almofadas+usadas%2Fsujas.%0A-+WC+sem+toalhas%2C+papel+higi%C3%A9nico+j%C3%A1+no+fim%2C+sem+l%C3%ADquido%2Fsabonete+para+as+m%C3%A3os.%0A-+Wi-fi+n%C3%A3o+funcionava%2C+TV+s%C3%B3+desligava+na+ficha+%28sem+comando%29.%0A%0ASuper+desagrad%C3%A1vel%21%0ADesaconselh%C3%A1vel+tanto+este+como+o+Suite+Douro%2C+uma+falta+de+respeito+para+com+quem+reserva. (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000023B1B64EDB0>: Failed to resolve 'translate.google.com' ([Errno 11001] getaddrinfo failed)"))

# %%
# Carregar o modelo linguístico do spaCy
nlp = spacy.load("en_core_web_sm")

# Personalizar a lista de stopwords: manter 'not'
custom_stopwords = STOP_WORDS - {"not"}

# Função de normalização do texto
def normalizar_texto(texto):
    if not isinstance(texto, str):
        return ""
    texto = texto.lower()  # converter para minúsculas
    texto = re.sub(r"[{}]".format(string.punctuation), "", texto)  # remover pontuação
    texto = re.sub(r"\s+", " ", texto).strip()  # remover espaços extra
    return texto

# Aplicar normalização
comentarios["Texto_Normalizado"] = comentarios["translated_text"].apply(normalizar_texto)

# Função de lematização com remoção criteriosa de stopwords
def lematizar(texto):
    if not isinstance(texto, str) or texto.strip() == "":
        return ""
    doc = nlp(texto)
    return " ".join([
        token.lemma_ for token in doc
        if token.text.lower() not in custom_stopwords and not token.is_punct
    ])

# Aplicar lematização
comentarios["Texto_Lematizado"] = comentarios["Texto_Normalizado"].apply(lematizar)

# Cálculo da polaridade com TextBlob (poderias adicionar VADER também, se desejado)
comentarios["Polaridade"] = comentarios["Texto_Lematizado"].apply(lambda x: TextBlob(x).sentiment.polarity)

# Visualizar primeiras linhas
comentarios[["translated_text", "Texto_Lematizado", "Polaridade"]].head()
# Out:
#                                      translated_text  \
# 0  I came here as part of a tour, and this restau...
# 1  Has to be the most delicious veal I've had in ...
# 2  Came here as part of a tour and very much appr...
# 3  Very good food and an excellent place to eat! ...
# 4  Great place for a good typical Portuguese food...
#
#                                     Texto_Lematizado  Polaridade
# 0  come tour restaurant save tour goat meat potat...    0.000000
# 1  delicious veal ve life probably good meat ve l...    0.583333
# 2  come tour appreciate enjoy food vibe service t...    0.240000
# 3  good food excellent place eat go group food ta...    0.850000
# 4  great place good typical portuguese food good ...    0.446667

# %% [markdown]
# **Refinement of the NLP Preprocessing Strategy:**
#
# Throughout the development process, the text preprocessing pipeline was progressively improved based on feedback and established NLP best practices. In particular, we incorporated recommendations from experts like Julia Silge to ensure a balanced approach between data cleaning and semantic preservation.
#
# This involved:
# - Retaining context-relevant stopwords (e.g., *not*) to maintain the polarity of expressions like *not good*.
# - Ensuring that automatic translations preserved emotional tone and idiomatic expressions as faithfully as possible.
# - Avoiding excessive simplification that might harm topic coherence or sentiment interpretation.

# %%
# Testar se expressões com negação mantêm o sentido após normalização
test_sentences = ["not good", "very bad", "absolutely amazing"]
for s in test_sentences:
    print("Lematizado:", lematizar(normalizar_texto(s)))
# Out:
# Lematizado: not good
# Lematizado: bad
# Lematizado: absolutely amazing

# %% [markdown]
# | Original Phrase       | Lemmatized Output       | Observations                                                                 |
# |-----------------------|--------------------------|------------------------------------------------------------------------------|
# | `not good`            | `not good`               | ✅ Negation preserved — ideal for sentiment analysis.                        |
# | `very bad`            | `bad`                    | ✅ Intensifier “very” correctly removed as a stopword; key term retained.    |
# | `absolutely amazing`  | `absolutely amazing`     | ✅ “absolutely” preserved — may indicate emphasis (acceptable depending on the context). |

# %%
comentarios.head()
# Out:
#    Cidade    Categoria           Nome_Local           Autor  \
# 0  Arouca  restaurante  Tasquinha da Quinta              IC
# 1  Arouca  restaurante  Tasquinha da Quinta    Preetam Nath
# 2  Arouca  restaurante  Tasquinha da Quinta         Roya MJ
# 3  Arouca  restaurante  Tasquinha da Quinta   Jonathan lugo
# 4  Arouca  restaurante  Tasquinha da Quinta  Benjamim Nande
#
#                                                Texto           Data  Rating  \
# 0  I came here as part of a tour, and this restau...  10 months ago       5
# 1  Has to be the most delicious veal I've had in ...     a year ago       5
# 2  Came here as part of a tour and very much appr...     a year ago       5
# 3  Very good food and an excellent place to eat! ...     a year ago       5
# 4  Great place for a good typical Portuguese food...   4 months ago       5
#
#   Idioma Data_Convertida                                    translated_text  \
# 0     en      2024-08-11  I came here as part of a tour, and this restau...
# 1     en      2024-06-11  Has to be the most delicious veal I've had in ...
# 2     en      2024-06-11  Came here as part of a tour and very much appr...
# 3     en      2024-06-11  Very good food and an excellent place to eat! ...
# 4     en      2025-02-11  Great place for a good typical Portuguese food...
#
#                                    Texto_Normalizado  \
# 0  i came here as part of a tour and this restaur...
# 1  has to be the most delicious veal ive had in m...
# 2  came here as part of a tour and very much appr...
# 3  very good food and an excellent place to eat w...
# 4  great place for a good typical portuguese food...
#
#                                     Texto_Lematizado  Polaridade
# 0  come tour restaurant save tour goat meat potat...    0.000000
# 1  delicious veal ve life probably good meat ve l...    0.583333
# 2  come tour appreciate enjoy food vibe service t...    0.240000
# 3  good food excellent place eat go group food ta...    0.850000
# 4  great place good typical portuguese food good ...    0.446667

# %%
# Calcular média da polaridade por local
average_polarity = comentarios.groupby("Nome_Local")["Polaridade"].mean().reset_index()
average_polarity.columns = ["Nome_Local", "Polaridade_Média"]

# Adicionar ao DataFrame original (merge)
comentarios = comentarios.merge(average_polarity, on="Nome_Local", how="left")

# %% [markdown]
# # === 5. EXPORTING FILES ===

# %%
avaliacoes.to_csv("ratings_clean.csv", index=False, encoding="utf-8-sig")
comentarios.to_csv("comments_clean.csv", index=False, encoding="utf-8-sig")

print("✅ Ficheiros tratados com sucesso! Dois CSVs gerados: 'ratings_clean.csv' e 'comments_clean.csv'")
# Out:
# ✅ Ficheiros tratados com sucesso! Dois CSVs gerados: 'ratings_clean.csv' e 'comments_clean.csv'

# %%
avaliacoes.head(20)
# Out:
#     Cidade   Categoria                                              Nome  \
# 0   Arouca  restaurant                               Tasquinha da Quinta
# 1   Arouca  restaurant                                      A Assembleia
# 2   Arouca  restaurant                                        Parlamento
# 3   Arouca  restaurant                                     Casa Testinha
# 4   Arouca  restaurant                                      Pedestre 142
# 5   Arouca  restaurant                               Tasquinho do Parque
# 6   Arouca  restaurant                                        Varandinha
# 7   Arouca  restaurant                                   Café Arouquense
# 8   Arouca  restaurant                            Quinta D'Além da Ponte
# 9   Arouca  restaurant                           Restaurante do Pedrogão
# 10  Arouca  restaurant                              Casa dos Bifes Silva
# 11  Arouca  restaurant                                     Paiva à Vista
# 12  Arouca  restaurant                   Abadessa Restaurante e Petiscos
# 13  Arouca  restaurant                                   Alto da Estrada
# 14  Arouca  restaurant                                     Casa no Campo
# 15  Arouca  restaurant                                           O Júlio
# 16  Arouca  restaurant  Casa dos Doces Conventuais de Arouca - Autêntica
# 17  Arouca  restaurant                                 Requinte do Paiva
# 18  Arouca  restaurant                                  Taberna da Toita
# 19  Arouca  restaurant                   Restaurante Passadiços do Paiva
#
#     Rating                                           Endereço  \
# 0      4.6         R. 1º de Maio 3, 4540-121 Arouca, Portugal
# 1      4.5       Tv. da Ribeira 11, 4540-102 Arouca, Portugal
# 2      4.6        Tv. da Ribeira 2, 4540-148 Arouca, Portugal
# 3      4.5         R. 1º de Maio 4, 4540-113 Arouca, Portugal
# 4      4.4  R. Dr. Ângelo Miranda 142 RC, 4540-140 Arouca,...
# 5      4.5  R. Dom Afonso Henriques 57 4540, Arouca, Portugal
# 6      4.4  Av. Reinaldo Noronha 39, 4540-181 Arouca, Port...
# 7      4.3         Av. 25 de Abril, 4540-102 Arouca, Portugal
# 8      4.5                Lugar do, 4540-606 Arouca, Portugal
# 9      4.8                          4540-445 Arouca, Portugal
# 10     4.4  Lugar do Paço Alvarenga, 4540-046 Arouca, Port...
# 11     4.3     Vilarinho - Canelas, 4540-257 Arouca, Portugal
# 12     5.0  R. Dr. Coelho da Rocha 8A, 4540-121 Arouca, Po...
# 13     4.1         Alto da Estrada, 4540-202 Arouca, Portugal
# 14     4.7                      4540-431 Espinheiro, Portugal
# 15     4.3                         4540-291 Escariz, Portugal
# 16     4.7      Av. 25 de Abril 24, 4540-102 Arouca, Portugal
# 17     4.6  XQVP+59 A 200 metros da entrada dos passadiços...
# 18     4.7           Cruz da Toita, 4540-528 Arouca, Portugal
# 19     4.5                  R326 1, 4540-031 Arouca, Portugal
#
#                                                 Tipos   Latitude  Longitude  \
# 0   restaurant, food, point_of_interest, establish...  40.929109  -8.245191
# 1   restaurant, bar, food, point_of_interest, esta...  40.928766  -8.247588
# 2   restaurant, food, point_of_interest, establish...  40.929011  -8.247392
# 3   restaurant, food, point_of_interest, establish...  40.928876  -8.245147
# 4   restaurant, food, point_of_interest, establish...  40.930185  -8.253210
# 5   restaurant, food, point_of_interest, establish...  40.927645  -8.248854
# 6   restaurant, food, point_of_interest, establish...  40.934069  -8.241372
# 7   cafe, restaurant, food, point_of_interest, est...  40.928469  -8.245599
# 8   restaurant, food, point_of_interest, establish...  40.939060  -8.341836
# 9   restaurant, food, point_of_interest, establish...  40.899020  -8.212277
# 10  restaurant, food, point_of_interest, establish...  40.968644  -8.159818
# 11  restaurant, cafe, food, point_of_interest, est...  40.952945  -8.185775
# 12  restaurant, food, point_of_interest, establish...  40.929133  -8.245461
# 13  restaurant, food, point_of_interest, establish...  40.928009  -8.255923
# 14  restaurant, food, point_of_interest, establish...  40.892675  -8.233592
# 15  restaurant, food, point_of_interest, establish...  40.941049  -8.403241
# 16  bakery, store, food, point_of_interest, establ...  40.928543  -8.247236
# 17  restaurant, food, point_of_interest, establish...  40.992847  -8.213995
# 18  restaurant, food, point_of_interest, establish...  40.929964  -8.272991
# 19  restaurant, food, point_of_interest, establish...  40.961288  -8.158794
#
#     Total_Reviews  id_unico Grupo_Tematico  Locais_Semelhantes_Perto
# 0            2154  d111a3c6       Serviços                       6.0
# 1            1788  54221336       Serviços                       6.0
# 2            2469  ca96ed20       Serviços                       7.0
# 3             623  348acace       Serviços                       6.0
# 4            1047  55a3ab0d       Serviços                       0.0
# 5             203  066473c6       Serviços                       2.0
# 6             721  dc4ee328       Serviços                       1.0
# 7             901  47e0eea2       Serviços                       6.0
# 8             423  61113e19       Serviços                       0.0
# 9             272  223ec896       Serviços                       0.0
# 10           1047  be9831ca       Serviços                       0.0
# 11            379  e2937d34       Serviços                       0.0
# 12             26  55c15277       Serviços                       6.0
# 13            713  a64e3cf3       Serviços                       1.0
# 14            617  038fff3f       Serviços                       0.0
# 15           1656  f8541610       Serviços                       0.0
# 16            750  e0b96ba9       Serviços                       5.0
# 17            234  48338770       Serviços                       0.0
# 18             37  039d41dd       Serviços                       0.0
# 19            126  cc2e3bff       Serviços                       0.0

# %%
comentarios.head(20)
# Out:
#     Cidade    Categoria           Nome_Local             Autor  \
# 0   Arouca  restaurante  Tasquinha da Quinta                IC
# 1   Arouca  restaurante  Tasquinha da Quinta      Preetam Nath
# 2   Arouca  restaurante  Tasquinha da Quinta           Roya MJ
# 3   Arouca  restaurante  Tasquinha da Quinta     Jonathan lugo
# 4   Arouca  restaurante  Tasquinha da Quinta    Benjamim Nande
# 5   Arouca  restaurante           Parlamento     Helena Borges
# 6   Arouca  restaurante           Parlamento        Greg Janes
# 7   Arouca  restaurante           Parlamento    Tiago Ferreira
# 8   Arouca  restaurante           Parlamento   Samuel Monteiro
# 9   Arouca  restaurante           Parlamento   Pini Shvartsman
# 10  Arouca  restaurante        Casa Testinha   Georgia Cardoso
# 11  Arouca  restaurante        Casa Testinha          Veronica
# 12  Arouca  restaurante        Casa Testinha               K M
# 13  Arouca  restaurante        Casa Testinha       David Aaron
# 14  Arouca  restaurante        Casa Testinha           Rap Par
# 15  Arouca  restaurante         A Assembleia         Ken Weary
# 16  Arouca  restaurante         A Assembleia  Lois Chi Hua Lai
# 17  Arouca  restaurante         A Assembleia          dia more
# 18  Arouca  restaurante         A Assembleia   Clover Sunshine
# 19  Arouca  restaurante         A Assembleia      Silvia Singh
#
#                                                 Texto           Data  Rating  \
# 0   I came here as part of a tour, and this restau...  10 months ago       5
# 1   Has to be the most delicious veal I've had in ...     a year ago       5
# 2   Came here as part of a tour and very much appr...     a year ago       5
# 3   Very good food and an excellent place to eat! ...     a year ago       5
# 4   Great place for a good typical Portuguese food...   4 months ago       5
# 5   Delicious food and super nice service. Generou...     a year ago       5
# 6   We loved this place! We stopped here on our wa...     a year ago       5
# 7   The food was delicious and the staff was frien...   5 months ago       5
# 8   Amazing food and wine. We had the house specia...     a year ago       5
# 9   we are the recommended steaks. very good. come...     a year ago       5
# 10  If you like to eat in a place that has an exce...   7 months ago       5
# 11  We showed up at closing time but the staff was...     a year ago       5
# 12  Some of the best fried chicken I have had. Fri...     a year ago       5
# 13  We arrived just for a glass of wine and ended ...    3 years ago       5
# 14  Delicious, quick, cheap traditional Portuguese...     a year ago       5
# 15  Incredible meal and service! Hands down this i...    3 years ago       5
# 16  We have enjoyed our lunch very much here.  The...     a year ago       5
# 17  This place is a hidden Gem!\nFirst we thought ...     a year ago       5
# 18  Brilliant meal. “Heaven on a plate”. Exquisite...    4 years ago       5
# 19  Love the food. The steak was amazing. The staf...     a year ago       5
#
#    Idioma Data_Convertida                                    translated_text  \
# 0      en      2024-08-11  I came here as part of a tour, and this restau...
# 1      en      2024-06-11  Has to be the most delicious veal I've had in ...
# 2      en      2024-06-11  Came here as part of a tour and very much appr...
# 3      en      2024-06-11  Very good food and an excellent place to eat! ...
# 4      en      2025-02-11  Great place for a good typical Portuguese food...
# 5      en      2024-06-11  Delicious food and super nice service. Generou...
# 6      en      2024-06-11  We loved this place! We stopped here on our wa...
# 7      en      2025-01-11  The food was delicious and the staff was frien...
# 8      en      2024-06-11  Amazing food and wine. We had the house specia...
# 9      en      2024-06-11  we are the recommended steaks. very good. come...
# 10     en      2024-11-11  If you like to eat in a place that has an exce...
# 11     en      2024-06-11  We showed up at closing time but the staff was...
# 12     en      2024-06-11  Some of the best fried chicken I have had. Fri...
# 13     en      2022-06-11  We arrived just for a glass of wine and ended ...
# 14     en      2024-06-11  Delicious, quick, cheap traditional Portuguese...
# 15     en      2022-06-11  Incredible meal and service! Hands down this i...
# 16     en      2024-06-11  We have enjoyed our lunch very much here.  The...
# 17     en      2024-06-11  This place is a hidden Gem!\nFirst we thought ...
# 18     en      2021-06-11  Brilliant meal. “Heaven on a plate”. Exquisite...
# 19     en      2024-06-11  Love the food. The steak was amazing. The staf...
#
#                                     Texto_Normalizado  \
# 0   i came here as part of a tour and this restaur...
# 1   has to be the most delicious veal ive had in m...
# 2   came here as part of a tour and very much appr...
# 3   very good food and an excellent place to eat w...
# 4   great place for a good typical portuguese food...
# 5   delicious food and super nice service generous...
# 6   we loved this place we stopped here on our way...
# 7   the food was delicious and the staff was frien...
# 8   amazing food and wine we had the house special...
# 9   we are the recommended steaks very good comes ...
# 10  if you like to eat in a place that has an exce...
# 11  we showed up at closing time but the staff was...
# 12  some of the best fried chicken i have had frie...
# 13  we arrived just for a glass of wine and ended ...
# 14  delicious quick cheap traditional portuguese f...
# 15  incredible meal and service hands down this is...
# 16  we have enjoyed our lunch very much here the r...
# 17  this place is a hidden gem first we thought we...
# 18  brilliant meal “heaven on a plate” exquisite s...
# 19  love the food the steak was amazing the staff ...
#
#                                      Texto_Lematizado  Polaridade  \
# 0   come tour restaurant save tour goat meat potat...    0.000000
# 1   delicious veal ve life probably good meat ve l...    0.583333
# 2   come tour appreciate enjoy food vibe service t...    0.240000
# 3   good food excellent place eat go group food ta...    0.850000
# 4   great place good typical portuguese food good ...    0.446667
# 5   delicious food super nice service generous amo...    0.444444
# 6   love place stop way town feel lucky stumble pl...    0.465385
# 7   food delicious staff friendly offer dessert drink    0.687500
# 8   amazing food wine house special vitela assada ...    0.365714
# 9   recommend steak good come side local rice fren...    0.285714
# 10  like eat place excellent food highly service q...    0.580000
# 11  show closing time staff kind serve good chicke...    0.213393
# 12  well fry chicken friendly staff quick attentiv...    0.133667
# 13  arrive glass wine end have dinner jao wonderfu...    0.176667
# 14  delicious quick cheap traditional portuguese f...    0.433333
# 15  incredible meal service hand incredible place ...    0.775000
# 16  enjoy lunch roast veal onion pepper carrot cab...    0.423333
# 17  place hidden gem think kinda feel awkward come...    0.267513
# 18  brilliant meal heaven plate exquisite service ...    0.680606
# 19             love food steak amazing staff friendly    0.491667
#
#     Polaridade_Média
# 0           0.424000
# 1           0.424000
# 2           0.424000
# 3           0.424000
# 4           0.424000
# 5           0.449752
# 6           0.449752
# 7           0.449752
# 8           0.449752
# 9           0.449752
# 10          0.307412
# 11          0.307412
# 12          0.307412
# 13          0.307412
# 14          0.307412
# 15          0.527624
# 16          0.527624
# 17          0.527624
# 18          0.527624
# 19          0.527624

# %%
avaliacoes['Total_Reviews'].isnull().sum()
# Out:
# 0
