# %%
import requests
import pandas as pd
import time
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Retrieve the API key
API_KEY = os.getenv("GOOGLE_API_KEY")

# 🏙️ Municípios da Área Metropolitana do Porto
cidades = ['Arouca', 'Espinho', 'Gondomar', 'Maia', 'Matosinhos', 'Oliveira de Azeméis',
           'Paredes', 'Penafiel', 'Porto', 'Póvoa de Varzim', 'Santa Maria da Feira',
           'Santo Tirso', 'São João da Madeira', 'Trofa', 'Valongo', 'Vila do Conde', 'Vila Nova de Gaia']

# 🔎 Categorias a pesquisar (expandido)
categorias = [
    "restaurant", "museum", "hotel", "bar", "tourist_attraction",
    "cafe", "church", "park", "natural_feature", "viewpoint", "trail", "lodging"
]

# 🔧 Função para buscar locais por tipo e cidade
def buscar_locais(cidade, tipo, pagetoken=None):
    url = 'https://maps.googleapis.com/maps/api/place/textsearch/json'
    parametros = {
        'query': f'{tipo} in {cidade}, Portugal',
        'key': API_KEY
    }
    if pagetoken:
        parametros['pagetoken'] = pagetoken

    resposta = requests.get(url, params=parametros)
    return resposta.json()

# 📦 Extrair dados dos resultados da API
def extrair_dados(resultados, cidade, categoria):
    dados = []
    for local in resultados:
        nome = local.get('name')
        rating = local.get('rating')
        endereco = local.get('formatted_address')
        tipos = ', '.join(local.get('types', []))
        dados.append([cidade, categoria, nome, rating, endereco, tipos])
    return dados

# 🗃️ Lista para guardar tudo
todos_dados = []

# 🔁 Recolher dados para cada cidade e categoria
for cidade in cidades:
    for categoria in categorias:
        print(f"📍 Buscar: {categoria} em {cidade}")
        resultados = buscar_locais(cidade, categoria)
        dados = extrair_dados(resultados.get("results", []), cidade, categoria)
        todos_dados.extend(dados)

        pagetoken = resultados.get("next_page_token")
        if pagetoken:
            time.sleep(2)  # Aguardar o token ficar ativo
            resultados2 = buscar_locais(cidade, categoria, pagetoken=pagetoken)
            dados2 = extrair_dados(resultados2.get("results", []), cidade, categoria)
            todos_dados.extend(dados2)

# 💾 Criar e guardar CSV
df = pd.DataFrame(todos_dados, columns=["Cidade", "Categoria", "Nome", "Rating", "Endereço", "Tipos"])
df.to_csv("google_places_AMP.csv", index=False, encoding='utf-8-sig')
print("✅ Dados exportados para 'google_places_AMP.csv'")
# Out:
# 📍 Buscar: restaurant em Arouca
# 📍 Buscar: museum em Arouca
# 📍 Buscar: hotel em Arouca
# 📍 Buscar: bar em Arouca
# 📍 Buscar: tourist_attraction em Arouca
# 📍 Buscar: cafe em Arouca
# 📍 Buscar: church em Arouca
# 📍 Buscar: park em Arouca
# 📍 Buscar: natural_feature em Arouca
# 📍 Buscar: viewpoint em Arouca
# 📍 Buscar: trail em Arouca
# 📍 Buscar: lodging em Arouca
# 📍 Buscar: restaurant em Espinho
# 📍 Buscar: museum em Espinho
# 📍 Buscar: hotel em Espinho
# 📍 Buscar: bar em Espinho
# 📍 Buscar: tourist_attraction em Espinho
# 📍 Buscar: cafe em Espinho
# 📍 Buscar: church em Espinho
# 📍 Buscar: park em Espinho
# 📍 Buscar: natural_feature em Espinho
# 📍 Buscar: viewpoint em Espinho
# 📍 Buscar: trail em Espinho
# 📍 Buscar: lodging em Espinho
# 📍 Buscar: restaurant em Gondomar
# 📍 Buscar: museum em Gondomar
# 📍 Buscar: hotel em Gondomar
# 📍 Buscar: bar em Gondomar
# 📍 Buscar: tourist_attraction em Gondomar
# 📍 Buscar: cafe em Gondomar
# 📍 Buscar: church em Gondomar
# 📍 Buscar: park em Gondomar
# 📍 Buscar: natural_feature em Gondomar
# 📍 Buscar: viewpoint em Gondomar
# 📍 Buscar: trail em Gondomar
# 📍 Buscar: lodging em Gondomar
# 📍 Buscar: restaurant em Maia
# 📍 Buscar: museum em Maia
# 📍 Buscar: hotel em Maia
# 📍 Buscar: bar em Maia
# 📍 Buscar: tourist_attraction em Maia
# 📍 Buscar: cafe em Maia
# 📍 Buscar: church em Maia
# 📍 Buscar: park em Maia
# 📍 Buscar: natural_feature em Maia
# 📍 Buscar: viewpoint em Maia
# 📍 Buscar: trail em Maia
# 📍 Buscar: lodging em Maia
# 📍 Buscar: restaurant em Matosinhos
# 📍 Buscar: museum em Matosinhos
# 📍 Buscar: hotel em Matosinhos
# 📍 Buscar: bar em Matosinhos
# 📍 Buscar: tourist_attraction em Matosinhos
# 📍 Buscar: cafe em Matosinhos
# 📍 Buscar: church em Matosinhos
# 📍 Buscar: park em Matosinhos
# 📍 Buscar: natural_feature em Matosinhos
# 📍 Buscar: viewpoint em Matosinhos
# 📍 Buscar: trail em Matosinhos
# 📍 Buscar: lodging em Matosinhos
# 📍 Buscar: restaurant em Oliveira de Azeméis
# 📍 Buscar: museum em Oliveira de Azeméis
# 📍 Buscar: hotel em Oliveira de Azeméis
# 📍 Buscar: bar em Oliveira de Azeméis
# 📍 Buscar: tourist_attraction em Oliveira de Azeméis
# 📍 Buscar: cafe em Oliveira de Azeméis
# 📍 Buscar: church em Oliveira de Azeméis
# 📍 Buscar: park em Oliveira de Azeméis
# 📍 Buscar: natural_feature em Oliveira de Azeméis
# 📍 Buscar: viewpoint em Oliveira de Azeméis
# 📍 Buscar: trail em Oliveira de Azeméis
# 📍 Buscar: lodging em Oliveira de Azeméis
# 📍 Buscar: restaurant em Paredes
# 📍 Buscar: museum em Paredes
# 📍 Buscar: hotel em Paredes
# 📍 Buscar: bar em Paredes
# 📍 Buscar: tourist_attraction em Paredes
# 📍 Buscar: cafe em Paredes
# 📍 Buscar: church em Paredes
# 📍 Buscar: park em Paredes
# 📍 Buscar: natural_feature em Paredes
# 📍 Buscar: viewpoint em Paredes
# 📍 Buscar: trail em Paredes
# 📍 Buscar: lodging em Paredes
# 📍 Buscar: restaurant em Penafiel
# 📍 Buscar: museum em Penafiel
# 📍 Buscar: hotel em Penafiel
# 📍 Buscar: bar em Penafiel
# 📍 Buscar: tourist_attraction em Penafiel
# 📍 Buscar: cafe em Penafiel
# 📍 Buscar: church em Penafiel
# 📍 Buscar: park em Penafiel
# 📍 Buscar: natural_feature em Penafiel
# 📍 Buscar: viewpoint em Penafiel
# 📍 Buscar: trail em Penafiel
# 📍 Buscar: lodging em Penafiel
# 📍 Buscar: restaurant em Porto
# 📍 Buscar: museum em Porto
# 📍 Buscar: hotel em Porto
# 📍 Buscar: bar em Porto
# 📍 Buscar: tourist_attraction em Porto
# 📍 Buscar: cafe em Porto
# 📍 Buscar: church em Porto
# 📍 Buscar: park em Porto
# 📍 Buscar: natural_feature em Porto
# 📍 Buscar: viewpoint em Porto
# 📍 Buscar: trail em Porto
# 📍 Buscar: lodging em Porto
# 📍 Buscar: restaurant em Póvoa de Varzim
# 📍 Buscar: museum em Póvoa de Varzim
# 📍 Buscar: hotel em Póvoa de Varzim
# 📍 Buscar: bar em Póvoa de Varzim
# 📍 Buscar: tourist_attraction em Póvoa de Varzim
# 📍 Buscar: cafe em Póvoa de Varzim
# 📍 Buscar: church em Póvoa de Varzim
# 📍 Buscar: park em Póvoa de Varzim
# 📍 Buscar: natural_feature em Póvoa de Varzim
# 📍 Buscar: viewpoint em Póvoa de Varzim
# 📍 Buscar: trail em Póvoa de Varzim
# 📍 Buscar: lodging em Póvoa de Varzim
# 📍 Buscar: restaurant em Santa Maria da Feira
# 📍 Buscar: museum em Santa Maria da Feira
# 📍 Buscar: hotel em Santa Maria da Feira
# 📍 Buscar: bar em Santa Maria da Feira
# 📍 Buscar: tourist_attraction em Santa Maria da Feira
# 📍 Buscar: cafe em Santa Maria da Feira
# 📍 Buscar: church em Santa Maria da Feira
# 📍 Buscar: park em Santa Maria da Feira
# 📍 Buscar: natural_feature em Santa Maria da Feira
# 📍 Buscar: viewpoint em Santa Maria da Feira
# 📍 Buscar: trail em Santa Maria da Feira
# 📍 Buscar: lodging em Santa Maria da Feira
# 📍 Buscar: restaurant em Santo Tirso
# 📍 Buscar: museum em Santo Tirso
# 📍 Buscar: hotel em Santo Tirso
# 📍 Buscar: bar em Santo Tirso
# 📍 Buscar: tourist_attraction em Santo Tirso
# 📍 Buscar: cafe em Santo Tirso
# 📍 Buscar: church em Santo Tirso
# 📍 Buscar: park em Santo Tirso
# 📍 Buscar: natural_feature em Santo Tirso
# 📍 Buscar: viewpoint em Santo Tirso
# 📍 Buscar: trail em Santo Tirso
# 📍 Buscar: lodging em Santo Tirso
# 📍 Buscar: restaurant em São João da Madeira
# 📍 Buscar: museum em São João da Madeira
# 📍 Buscar: hotel em São João da Madeira
# 📍 Buscar: bar em São João da Madeira
# 📍 Buscar: tourist_attraction em São João da Madeira
# 📍 Buscar: cafe em São João da Madeira
# 📍 Buscar: church em São João da Madeira
# 📍 Buscar: park em São João da Madeira
# 📍 Buscar: natural_feature em São João da Madeira
# 📍 Buscar: viewpoint em São João da Madeira
# 📍 Buscar: trail em São João da Madeira
# 📍 Buscar: lodging em São João da Madeira
# 📍 Buscar: restaurant em Trofa
# 📍 Buscar: museum em Trofa
# 📍 Buscar: hotel em Trofa
# 📍 Buscar: bar em Trofa
# 📍 Buscar: tourist_attraction em Trofa
# 📍 Buscar: cafe em Trofa
# 📍 Buscar: church em Trofa
# 📍 Buscar: park em Trofa
# 📍 Buscar: natural_feature em Trofa
# 📍 Buscar: viewpoint em Trofa
# 📍 Buscar: trail em Trofa
# 📍 Buscar: lodging em Trofa
# 📍 Buscar: restaurant em Valongo
# 📍 Buscar: museum em Valongo
# 📍 Buscar: hotel em Valongo
# 📍 Buscar: bar em Valongo
# 📍 Buscar: tourist_attraction em Valongo
# 📍 Buscar: cafe em Valongo
# 📍 Buscar: church em Valongo
# 📍 Buscar: park em Valongo
# 📍 Buscar: natural_feature em Valongo
# 📍 Buscar: viewpoint em Valongo
# 📍 Buscar: trail em Valongo
# 📍 Buscar: lodging em Valongo
# 📍 Buscar: restaurant em Vila do Conde
# 📍 Buscar: museum em Vila do Conde
# 📍 Buscar: hotel em Vila do Conde
# 📍 Buscar: bar em Vila do Conde
# 📍 Buscar: tourist_attraction em Vila do Conde
# 📍 Buscar: cafe em Vila do Conde
# 📍 Buscar: church em Vila do Conde
# 📍 Buscar: park em Vila do Conde
# 📍 Buscar: natural_feature em Vila do Conde
# 📍 Buscar: viewpoint em Vila do Conde
# 📍 Buscar: trail em Vila do Conde
# 📍 Buscar: lodging em Vila do Conde
# 📍 Buscar: restaurant em Vila Nova de Gaia
# 📍 Buscar: museum em Vila Nova de Gaia
# 📍 Buscar: hotel em Vila Nova de Gaia
# 📍 Buscar: bar em Vila Nova de Gaia
# 📍 Buscar: tourist_attraction em Vila Nova de Gaia
# 📍 Buscar: cafe em Vila Nova de Gaia
# 📍 Buscar: church em Vila Nova de Gaia
# 📍 Buscar: park em Vila Nova de Gaia
# 📍 Buscar: natural_feature em Vila Nova de Gaia
# 📍 Buscar: viewpoint em Vila Nova de Gaia
# 📍 Buscar: trail em Vila Nova de Gaia
# 📍 Buscar: lodging em Vila Nova de Gaia
# ✅ Dados exportados para 'dados_google_places_AMP_2.csv'
